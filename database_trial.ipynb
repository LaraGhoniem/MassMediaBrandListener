# %%
from pymongo import MongoClient

# %%
cluster = MongoClient("mongodb+srv://Cluster22:Mj8sP4uq8GtrOJBN@cluster22334.jy8xlkd.mongodb.net")

# %%
db = cluster["test"]
collection = db["test"]

# %%
post1 = {"_id": 0, "name": "John", "score": 1}
post2 = {"_id": 1, "name": "Mike", "score": 2}

# %%
collection.insert_many([post1, post2])

# %%
results = collection.find({"_id": 0})
print(results)

# %%
print([i for i in results])
# Out:
# [{'_id': 0, 'name': 'John', 'score': 1}]

# %%
results = collection.update_one({"_id":0}, {"$set":{"score": 3}})

# %%
from bson import ObjectId
listener_database = db["listeners"]
listener_database.update_one({"_id":ObjectId("63fe3322e7e90c6d54d15ccf")},{"$set":{"result": "test"}})

# %%
from modules.twitter_module.twitter_api import TwitterAPI
twitter_results = TwitterAPI("Saco").getResponse("ar")
# print(TwitterAPI("Saco").getLinksAndDates(twitter_results["tweet_data"]))
print((twitter_results))
# Out:
# Saco
# ...

# %%
print(twitter_results)
# Out:
# [{'preprocessed_text': [' ⠀  ⠀  ⠀  ⠀  ⠀  ⠀  ⠀  ⠀  ⠀    \n\nكل عام وامهاتنا بالف خير وصحه وسلامه\nالام نعمة لا تعوض \n@Saco_KSA\n 😍♥️♥️\n\n#يوم_الام'], 'tweet_data': [{'id': '1636556214627704833', 'lang': 'ar', 'entities': {'mentions': [{'start': 0, 'end': 9, 'username': 'Saco_KSA', 'id': '351516603'}, {'start': 97, 'end': 106, 'username': 'Saco_KSA', 'id': '351516603'}], 'hashtags': [{'start': 115, 'end': 124, 'tag': 'يوم_الام'}]}, 'text': '@Saco_KSA ⠀  ⠀  ⠀  ⠀  ⠀  ⠀  ⠀  ⠀  ⠀    \n\nكل عام وامهاتنا بالف خير وصحه وسلامه\nالام نعمة لا تعوض \n@Saco_KSA\n 😍♥️♥️\n\n#يوم_الام', 'author_id': '1450892989178449929', 'edit_history_tweet_ids': ['1636556214627704833'], 'created_at': '2023-03-17T02:33:01.000Z', 'public_metrics': {'retweet_count': 0, 'reply_count': 0, 'like_count': 0, 'quote_count': 0, 'impression_count': 13}, 'in_reply_to_user_id': '351516603'}]}, {'preprocessed_text': [' كراسي مكتبية \n،\n\n،\n\n@Saco_KSA \n\n#ساكو'], 'tweet_data': [{'edit_history_tweet_ids': ['16364942793328394
# ...

# %%
from modules.news_module.news import NewsApi
news_array,news_titles_array,links = NewsApi("Egypt").article_search()
print(links)
# Out:
# [{'source': {'id': None, 'name': 'Aljazeera.net'}, 'author': 'محمود سامي', 'title': 'شكري في سوريا وتركيا.. زيارة تضامنية أم للتطبيع مع أنقرة وكسر عزلة الأسد؟', 'description': 'تحت لافتة المساعدات الإنسانية، شهدت الدبلوماسية المصرية تحركات متسارعة بزيارة وزير الخارجية سامح شكري سوريا وتركيا لتقديم المساعدات المصرية لضحايا الزلزال المدمر، لكن هل هناك رسائل سياسية أيضا؟', 'url': 'https://www.aljazeera.net/politics/2023/2/28/%d8%b4%d9%83%d8%b1%d9%8a-%d9%81%d9%8a-%d8%b3%d9%88%d8%b1%d9%8a%d8%a7-%d9%88%d8%aa%d8%b1%d9%83%d9%8a%d8%a7-%d8%a7%d9%84%d9%85%d8%b3%d8%a7%d8%b9%d8%af%d8%a7%d8%aa-%d9%81%d9%82%d8%b7-%d8%a3%d9%85', 'urlToImage': 'https://www.aljazeera.net/wp-content/uploads/2023/02/13-6.jpg?resize=1920%2C1280', 'publishedAt': '2023-02-28T06:49:26Z', 'content': '- .\r\n 10 - - .\r\n - - " " .\r\n ( ) " " .\r\n .\r\n .\r\n 2011.. " " pic.twitter.com/9pH0GDC441\r\n (@AJArabic) February 27, 2023\r\n- - - - " " .\r\n .\r\n .\r\n . " " .\r\n . pic.twitter.com/ufOkhucs6X\r\n Egypt MFA Spok… [
# ...

# %%
from modules.youtube_module import youtube_handler
youtube = youtube_handler.Youtube("@Sidemen")
youtube.download("modules/youtube_module/downloads")
youtube_handler.Youtube.remove_files_from_dir("modules/youtube_module/downloads")
